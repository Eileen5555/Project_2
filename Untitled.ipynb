# %%
import pandas as pd

# %%
df_demo = pd.read_csv('../data/raw/df_final_demo.txt')
df_clients = pd.read_csv('../data/raw/df_final_experiment_clients.txt')
df_web_data_1 = pd.read_csv('../data/raw/df_final_web_data_pt_1.txt')
df_web_data_2 = pd.read_csv('../data/raw/df_final_web_data_pt_2.txt')

# %%
display('df_demo',df_demo)
# Out:
# 'df_demo'
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
display('df_clients',df_clients)
# Out:
# 'df_clients'
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
display('df_web_data_1', df_web_data_1)
# Out:
# 'df_web_data_1'
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
display('df_web_data_2',df_web_data_2)
# Out:
# 'df_web_data_2'
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##############################################DAY 1&2 WEEK 5 ###################################################################
# Check the shape of each dataframe
print(df_demo.shape)
print(df_clients.shape)
print(df_web_data_1.shape)
print(df_web_data_2.shape)

# Get basic statistics
print(df_demo.describe())
print(df_clients.describe())
print(df_web_data_1.describe())
print(df_web_data_2.describe())

# Check for missing values
print(df_demo.isnull().sum())
print(df_clients.isnull().sum())
print(df_web_data_1.isnull().sum())
print(df_web_data_2.isnull().sum())
# Out:
# (70609, 9)
# (70609, 2)
# (343141, 5)
# (412264, 5)
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  7.060900e+04    70595.000000      70595.000000  70594.000000
# mean   5.004992e+06       12.052950        150.659367     46.442240
# std    2.877278e+06        6.871819         82.089854     15.591273
# min    1.690000e+02        2.000000         33.000000     13.500000
# 25%    2.519329e+06        6.000000         82.000000     32.500000
# 50%    5.016978e+06       11.000000        136.000000     47.000000
# 75%    7.483085e+06       16.000000        192.000000     59.000000
# max    9.999839e+06       62.000000        749.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  70595.000000  7.059500e+04  70595.000000   70595.000000
# mean       2.255528  1.474452e+05      3.382478       5.566740
# std        0.534997  3.015087e+05      2.236580       2.353286
# ...

# %%
# Distribution of clients by gender
plt.figure(figsize=(10, 5))
sns.countplot(x='gendr', data=df_demo, order=df_demo['gendr'].value_counts().index)
plt.title('Distribution of Clients by Gender')
plt.show()

# %%
# Distribution of clients by age
plt.figure(figsize=(10, 5))
sns.histplot(df_demo['clnt_age'], bins=30, kde=True)
plt.title('Distribution of Clients by Age')
plt.xlabel('Age')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Tenure analysis
plt.figure(figsize=(10, 5))
sns.histplot(df_demo['clnt_tenure_yr'], bins=20, kde=True)
plt.title('Distribution of Clients by Tenure (Years)')
plt.xlabel('Tenure (Years)')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Average age of clients
avg_age = df_demo['clnt_age'].mean()
print(f'Average age of clients: {avg_age}')

# Average tenure of clients
avg_tenure = df_demo['clnt_tenure_yr'].mean()
print(f'Average tenure of clients: {avg_tenure}')

# Correlation between age and tenure
plt.figure(figsize=(10, 5))
sns.scatterplot(x='clnt_age', y='clnt_tenure_yr', data=df_demo)
plt.title('Correlation between Age and Tenure')
plt.xlabel('Client Age')
plt.ylabel('Client Tenure (Years)')
plt.show()
# Out:
# Average age of clients: 46.442240133722414
# Average tenure of clients: 12.052949925632127

# %%
# Distribution of balances
plt.figure(figsize=(10, 5))
sns.histplot(df_demo['bal'], bins=30, kde=True)
plt.title('Distribution of Client Balances')
plt.xlabel('Balance')
plt.show()

# Analyzing client logons
plt.figure(figsize=(10, 5))
sns.histplot(df_demo['logons_6_mnth'], bins=9, kde=False)
plt.title('Distribution of Client Logons (Last 6 Months)')
plt.xlabel('Number of Logons')
plt.show()

# Analyzing client calls
plt.figure(figsize=(10, 5))
sns.histplot(df_demo['calls_6_mnth'], bins=7, kde=False)
plt.title('Distribution of Client Calls (Last 6 Months)')
plt.xlabel('Number of Calls')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Merge client demographics with web data
df_web_data = pd.concat([df_web_data_1, df_web_data_2], ignore_index=True)
df_merged = df_demo.merge(df_clients, on='client_id', how='left').merge(df_web_data, on='client_id', how='left')

# Display the merged dataframe
print(df_merged.head())

# Analyze merged data
visit_counts = df_merged.groupby('Variation')['visit_id'].count().reset_index()
visit_counts.columns = ['Variation', 'Visit Count']
print(visit_counts)

# Plot the distribution of visits by client type
plt.figure(figsize=(10, 5))
sns.barplot(x='Variation', y='Visit Count', data=visit_counts)
plt.title('Visit Counts by Client Type')
plt.show()

# Separate visit counts by client type
control_visits = client_visit_counts[client_visit_counts['Variation'] == 'Control']['visit_count']
test_visits = client_visit_counts[client_visit_counts['Variation'] == 'Test']['visit_count']

from scipy.stats import chi2_contingency

# Extract visit counts for each group
control_visits = df_merged[df_merged['Variation'] == 'Control']['visit_id'].value_counts()
test_visits = df_merged[df_merged['Variation'] == 'Test']['visit_id'].value_counts()


# Step 1: Prepare the Data
visit_counts = df_merged.groupby('Variation')['visit_id'].count().reset_index()
visit_counts.columns = ['Variation', 'Visit Count']
print(visit_counts)

# Create a contingency table
contingency_table = pd.pivot_table(df_merged, values='visit_id', index='Variation', aggfunc='count').reset_index()
contingency_table.columns = ['Variation', 'Visit Count']
contingency_table = contingency_table.set_index('Variation').T
print(contingency_table)

# Step 2: Perform the Chi-Square Test
chi2_stat, p_val, dof, ex = chi2_contingency(contingency_table)

# Step 3: Interpret the Results
print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-Value: {p_val}")

# Determine if the difference is statistically significant
alpha = 0.05
if p_val < alpha:
    print("The difference in visit counts between Test and Control groups is statistically significant.")
else:
    print("The difference in visit counts between Test and Control groups is not statistically significant.")
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1     836976             6.0              73.0      60.5     U        2.0
# 2     836976             6.0              73.0      60.5     U        2.0
# 3     836976             6.0              73.0      60.5     U        2.0
# 4     836976             6.0              73.0      60.5     U        2.0
#
#        bal  calls_6_mnth  logons_6_mnth Variation            visitor_id  \
# 0  45105.3           6.0            9.0      Test  427070339_1413275162
# 1  45105.3           6.0            9.0      Test  427070339_1413275162
# 2  45105.3           6.0            9.0      Test  427070339_1413275162
# 3  45105.3           6.0            9.0      Test  427070339_1413275162
# 4  45105.3           6.0            9.0      Test  427070339_1413275162
#
#                       visit_id process_step            date_time
# ...

# %%
##############################################DAY 3 WEEK 5 ###################################################################
#merge data frames 
df_merged = pd.merge(df_web_data, df_clients, on='client_id')

# Convert date_time to datetime
df_merged['date_time'] = pd.to_datetime(df_merged['date_time'])

# Sort values by client_id and date_time
df_merged = df_merged.sort_values(by=['client_id', 'date_time'])

# Calculate time differences
df_merged['time_diff'] = df_merged.groupby('client_id')['date_time'].diff()

# Identify previous step
df_merged['prev_step'] = df_merged.groupby('client_id')['process_step'].shift(1)


def calculate_completion_rate(df):
    total_users = df['client_id'].nunique()
    completed_users = df[df['process_step'] == 'confirm']['client_id'].nunique()
    return completed_users / total_users * 100

def calculate_avg_time_per_step(df):
    return df.groupby('process_step')['time_diff'].mean()

def calculate_error_rate(df):
    df['error'] = df['process_step'] < df['prev_step']
    return df['error'].mean() * 100

def calculate_drop_off_rates(df, total_users):
    drop_off_counts = df.groupby('process_step')['client_id'].nunique()
    return drop_off_counts / total_users * 100

def calculate_bounce_rate(df):
    first_steps = df.groupby('client_id').first().reset_index()
    return (first_steps['process_step'] != 'confirm').mean() * 100

# %%
# Separate control and test groups
df_control = df_merged[df_merged['Variation'] == 'Control']
df_test = df_merged[df_merged['Variation'] == 'Test']

# Control group KPIs
control_completion_rate = calculate_completion_rate(df_control)
control_avg_time_per_step = calculate_avg_time_per_step(df_control)
control_error_rate = calculate_error_rate(df_control)
control_drop_off_rates = calculate_drop_off_rates(df_control, df_control['client_id'].nunique())
control_bounce_rate = calculate_bounce_rate(df_control)

# Test group KPIs
test_completion_rate = calculate_completion_rate(df_test)
test_avg_time_per_step = calculate_avg_time_per_step(df_test)
test_error_rate = calculate_error_rate(df_test)
test_drop_off_rates = calculate_drop_off_rates(df_test, df_test['client_id'].nunique())
test_bounce_rate = calculate_bounce_rate(df_test)

# Display results
print(f"Control Group - Completion Rate: {control_completion_rate:.2f}%")
print(f"Control Group - Average Time per Step:\n{control_avg_time_per_step}")
print(f"Control Group - Error Rate: {control_error_rate:.2f}%")
print(f"Control Group - Drop-off Rates:\n{control_drop_off_rates}")
print(f"Control Group - Bounce Rate: {control_bounce_rate:.2f}%")

print(f"\nTest Group - Completion Rate: {test_completion_rate:.2f}%")
print(f"Test Group - Average Time per Step:\n{test_avg_time_per_step}")
print(f"Test Group - Error Rate: {test_error_rate:.2f}%")
print(f"Test Group - Drop-off Rates:\n{test_drop_off_rates}")
print(f"Test Group - Bounce Rate: {test_bounce_rate:.2f}%")
# Out:
# Control Group - Completion Rate: 65.59%
# Control Group - Average Time per Step:
# process_step
# confirm   0 days 18:21:17.307379630
# start     4 days 05:57:44.544592030
# step_1    0 days 00:30:38.781647281
# step_2    0 days 00:00:39.342259834
# step_3    0 days 00:09:35.220494575
# Name: time_diff, dtype: timedelta64[ns]
# Control Group - Error Rate: 18.78%
# Control Group - Drop-off Rates:
# process_step
# confirm    65.587285
# start      99.426313
# step_1     85.636580
# step_2     79.253782
# step_3     74.035356
# Name: client_id, dtype: float64
# Control Group - Bounce Rate: 99.84%
#
# Test Group - Completion Rate: 69.29%
# Test Group - Average Time per Step:
# process_step
# confirm   1 days 05:00:32.783103231
# start     3 days 02:55:49.873986735
# step_1    0 days 00:22:19.804570955
# step_2    0 days 00:01:51.212471355
# step_3    0 days 00:12:18.920516488
# Name: time_diff, dtype: timedelta64[ns]
# Test Group - Error Rate: 20.81%
# Test Group - Drop-off Rates:
# ...

# %%
comparison = pd.DataFrame({
    'Metric': ['Completion Rate', 'Average Time per Step', 'Error Rate', 'Drop-off Rates', 'Bounce Rate'],
    'Control': [
        f"{control_completion_rate:.2f}%",
        control_avg_time_per_step.to_string(),
        f"{control_error_rate:.2f}%",
        control_drop_off_rates.to_string(),
        f"{control_bounce_rate:.2f}%"
    ],
    'Test': [
        f"{test_completion_rate:.2f}%",
        test_avg_time_per_step.to_string(),
        f"{test_error_rate:.2f}%",
        test_drop_off_rates.to_string(),
        f"{test_bounce_rate:.2f}%"
    ]
})

print(comparison)
# Out:
#                   Metric                                            Control  \
# 0        Completion Rate                                             65.59%
# 1  Average Time per Step  process_step\nconfirm   0 days 18:21:17.307379...
# 2             Error Rate                                             18.78%
# 3         Drop-off Rates  process_step\nconfirm    65.587285\nstart     ...
# 4            Bounce Rate                                             99.84%
#
#                                                 Test
# 0                                             69.29%
# 1  process_step\nconfirm   1 days 05:00:32.783103...
# 2                                             20.81%
# 3  process_step\nconfirm    69.293236\nstart     ...
# 4                                             99.16%

# %%
# Prepare data
control_avg_time_per_step = control_avg_time_per_step.reset_index()
test_avg_time_per_step = test_avg_time_per_step.reset_index()

# Completion Rate
plt.figure(figsize=(10, 5))
sns.barplot(x=['Control', 'Test'], y=[control_completion_rate, test_completion_rate])
plt.title('Completion Rate')
plt.ylabel('Percentage')
plt.show()

# Error Rate
plt.figure(figsize=(10, 5))
sns.barplot(x=['Control', 'Test'], y=[control_error_rate, test_error_rate])
plt.title('Error Rate')
plt.ylabel('Percentage')
plt.show()

# Bounce Rate
plt.figure(figsize=(10, 5))
sns.barplot(x=['Control', 'Test'], y=[control_bounce_rate, test_bounce_rate])
plt.title('Bounce Rate')
plt.ylabel('Percentage')
plt.show()

# Average Time per Step
plt.figure(figsize=(12, 6))
plt.plot(control_avg_time_per_step['process_step'], control_avg_time_per_step['time_diff'], label='Control', marker='o')
plt.plot(test_avg_time_per_step['process_step'], test_avg_time_per_step['time_diff'], label='Test', marker='o')
plt.title('Average Time per Step')
plt.xlabel('Process Step')
plt.ylabel('Time (Seconds)')
plt.legend()
plt.show()

# Drop-off Rates
control_drop_off_rates = control_drop_off_rates.reset_index()
test_drop_off_rates = test_drop_off_rates.reset_index()

plt.figure(figsize=(12, 6))
width = 0.4
r1 = range(len(control_drop_off_rates))
r2 = [x + width for x in r1]

plt.bar(r1, control_drop_off_rates['client_id'], color='b', width=width, edgecolor='grey', label='Control')
plt.bar(r2, test_drop_off_rates['client_id'], color='r', width=width, edgecolor='grey', label='Test')

plt.xlabel('Process Step')
plt.ylabel('Drop-off Rate (%)')
plt.title('Drop-off Rates by Process Step')
plt.xticks([r + width/2 for r in range(len(control_drop_off_rates))], control_drop_off_rates['process_step'])
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
##############################################DAY 4&5 WEEK 5 ###################################################################

import numpy as np
from statsmodels.stats.proportion import proportions_ztest
from scipy.stats import ttest_ind

# Merge df_demo with df_control and df_test on 'client_id'
df_control_merged = df_control.merge(df_demo[['client_id', 'clnt_age']], on='client_id', how='left')
df_test_merged = df_test.merge(df_demo[['client_id', 'clnt_age']], on='client_id', how='left')

# %%
# Calculate completion rates
control_completion_rate = df_control_merged[df_control_merged['process_step'] == 'confirm']['client_id'].nunique() / df_control_merged['client_id'].nunique()
test_completion_rate = df_test_merged[df_test_merged['process_step'] == 'confirm']['client_id'].nunique() / df_test_merged['client_id'].nunique()

# Calculate sample sizes and successes
n_control = df_control_merged['client_id'].nunique()
n_test = df_test_merged['client_id'].nunique()
successes_control = df_control_merged[df_control_merged['process_step'] == 'confirm']['client_id'].nunique()
successes_test = df_test_merged[df_test_merged['process_step'] == 'confirm']['client_id'].nunique()

# Two-proportion z-test for completion rates
count = np.array([successes_control, successes_test])
nobs = np.array([n_control, n_test])
stat, pval = proportions_ztest(count, nobs)
print(f"Z-test for completion rates: p-value = {pval:.4f}")

# One-proportion z-test for cost-effectiveness threshold
effect_size = 0.05
pooled_success_rate = (successes_control + successes_test) / (n_control + n_test)
standard_error = np.sqrt(pooled_success_rate * (1 - pooled_success_rate) * (1/n_control + 1/n_test))
test_statistic = (test_completion_rate - control_completion_rate - effect_size) / standard_error
pval_threshold = 1 - proportions_ztest([successes_control, successes_test], [n_control, n_test])[1]
print(f"One-proportion z-test for cost-effectiveness threshold: p-value = {pval_threshold:.4f}")
# Out:
# Z-test for completion rates: p-value = 0.0000
# One-proportion z-test for cost-effectiveness threshold: p-value = 1.0000

# %%
df_demo_clean = df_demo.copy()

# Calculate the median tenure (excluding missing values)
median_tenure = df_demo_clean['clnt_tenure_yr'].median()

# Impute missing values with the median
df_demo_clean['clnt_tenure_yr'].fillna(median_tenure, inplace=True)

# Merge df_demo with df_clients to get Variation information
df_demo_merged = df_demo_clean .merge(df_clients, on='client_id')

# Plot the distribution of tenure for each group
plt.figure(figsize=(10, 5))
sns.histplot(data=df_demo_merged, x='clnt_tenure_yr', hue='Variation', bins=20, kde=True)
plt.title('Distribution of Clients by Tenure (Years) for Test and Control Groups')
plt.xlabel('Tenure (Years)')
plt.ylabel('Frequency')
plt.legend(title='Variation', labels=['Control', 'Test'])
plt.show()

print(median_tenure)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 11.0

# %%
# Separate the tenure data for Test and Control groups
control_tenure = df_demo_merged[df_demo_merged['Variation'] == 'Control']['clnt_tenure_yr']
test_tenure = df_demo_merged[df_demo_merged['Variation'] == 'Test']['clnt_tenure_yr']

# Perform the two-sample t-test
t_stat, p_value = ttest_ind(control_tenure, test_tenure, equal_var=False)  # Use Welch's t-test

# Print the results
print(f"T-statistic: {t_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
if p_value < 0.05:
    print("The difference in client tenure between the Test and Control groups is statistically significant.")
else:
    print("The difference in client tenure between the Test and Control groups is not statistically significant.")
# Out:
# T-statistic: 1.7123
# P-value: 0.0868
# The difference in client tenure between the Test and Control groups is not statistically significant.

# %%
# Plot the distribution of age for each group
plt.figure(figsize=(10, 5))
sns.histplot(data=df_demo_merged, x='clnt_age', hue='Variation', bins=30, kde=True)
plt.title('Distribution of Clients by Age for Test and Control Groups')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend(title='Variation', labels=['Control', 'Test'])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Perform Chi-Square test
chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-Square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
if p_value < 0.05:
    print("There is a statistically significant association between age category and client type.")
else:
    print("There is no statistically significant association between age category and client type.")
# Out:
# Chi-Square Statistic: 0.0000
# P-value: 1.0000
# There is no statistically significant association between age category and client type.

# %%
# Completion Rate
plt.figure(figsize=(10, 5))
sns.barplot(x=['Control', 'Test'], y=[control_completion_rate, test_completion_rate])
plt.title('Completion Rate')
plt.ylabel('Percentage')
# Adding labels to the bars
for i in range(len(groups)):
    plt.text(i, completion_rates[i] + 1, f'{completion_rates[i]:.2f}%', ha='center', va='bottom')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[271], line 8
#       6 # Adding labels to the bars
#       7 for i in range(len(groups)):
# ----> 8     plt.text(i, completion_rates[i] + 1, f'{completion_rates[i]:.2f}%', ha='center', va='bottom')
#       9 plt.show()
#
# NameError: name 'completion_rates' is not defined

# %%
display (df_mer)
# Out:
#         client_id             visitor_id                      visit_id  \
# 304863        169  201385055_71273495308  749567106_99161211863_557568
# 304862        169  201385055_71273495308  749567106_99161211863_557568
# 304861        169  201385055_71273495308  749567106_99161211863_557568
# 304860        169  201385055_71273495308  749567106_99161211863_557568
# 304859        169  201385055_71273495308  749567106_99161211863_557568
# ...           ...                    ...                           ...
# 292958    9999839  948322592_28990736246  715530422_68620416793_515645
# 292957    9999839  948322592_28990736246  715530422_68620416793_515645
# 292956    9999839  948322592_28990736246  715530422_68620416793_515645
# 292955    9999839  948322592_28990736246  715530422_68620416793_515645
# 292954    9999839  948322592_28990736246  715530422_68620416793_515645
#
#        process_step           date_time Variation       time_diff prev_step
# ...

# %%
# Ensure the 'date_time' column is in datetime format
df_merged['date_time'] = pd.to_datetime(df_merged['date_time'])

# Group by 'client_id' and 'visit_id', find the earliest date for each group
earliest_dates = df_merged.groupby(['client_id'])['date_time'].transform('min')

# Mark rows with the earliest date as first engagements
df_merged['first_engagement'] = df_merged['date_time'] == earliest_dates

df_with_first_engagement = df_merged.copy()

# Find visit IDs where first engagement is True
visit_ids_with_true_first_engagement = df_with_first_engagement.loc[df_with_first_engagement['first_engagement'], 'visit_id'].unique()

# Update 'first_engagement' column based on visit IDs with True first engagement
df_with_first_engagement['first_engagement'] = df_with_first_engagement['visit_id'].isin(visit_ids_with_true_first_engagement)

# Convert boolean values back to 'True' and 'False' strings
df_with_first_engagement['first_engagement'] = df_with_first_engagement['first_engagement'].map({True: 'True', False: 'False'})

# Display the dataframe with the new column
display(df_with_first_engagement.head(20))

unique_first_engagement_values = df_with_first_engagement['first_engagement'].value_counts()

print(unique_first_engagement_values)
# Out:
#         client_id             visitor_id                      visit_id  \
# 304863        169  201385055_71273495308  749567106_99161211863_557568
# 304862        169  201385055_71273495308  749567106_99161211863_557568
# 304861        169  201385055_71273495308  749567106_99161211863_557568
# 304860        169  201385055_71273495308  749567106_99161211863_557568
# 304859        169  201385055_71273495308  749567106_99161211863_557568
# 77131         555  402506806_56087378777  637149525_38041617439_716659
# 77130         555  402506806_56087378777  637149525_38041617439_716659
# 77129         555  402506806_56087378777  637149525_38041617439_716659
# 77128         555  402506806_56087378777  637149525_38041617439_716659
# 77127         555  402506806_56087378777  637149525_38041617439_716659
# 147820        647   66758770_53988066587   40369564_40101682850_311847
# 147819        647   66758770_53988066587   40369564_40101682850_311847
# ...

# %%
def calculate_completion_rate(df):
    total_users = df['visitor_id'].nunique()
    completed_users = df[df['process_step'] == 'confirm']['visitor_id'].nunique()
    
    if total_users == 0:
        return 0  # Return 0 if there are no users
    else:
        return completed_users / total_users * 100



# Separate DataFrame into test and control groups
test_df = df_with_first_engagement[df_with_first_engagement['Variation'] == 'Test']
control_df = df_with_first_engagement[df_with_first_engagement['Variation'] == 'Control']

# Calculate completion rate for first-time and repeated visits in test and control groups
test_first_time_completion_rate = calculate_completion_rate(test_df[test_df['first_engagement'] == 'True'])
test_repeated_completion_rate = calculate_completion_rate(test_df[test_df['first_engagement'] == 'False'])
control_first_time_completion_rate = calculate_completion_rate(control_df[control_df['first_engagement'] == 'True'])
control_repeated_completion_rate = calculate_completion_rate(control_df[control_df['first_engagement'] == 'False'])

# Plotting
labels = ['First Time', 'Repeated']
control_completion_rates = [control_first_time_completion_rate, control_repeated_completion_rate]
test_completion_rates = [test_first_time_completion_rate, test_repeated_completion_rate]


x = range(len(labels))
width = 0.35

fig, ax = plt.subplots()
bars1 = ax.bar(x, control_completion_rates, width, label='Control')
bars2 = ax.bar([i + width for i in x], test_completion_rates, width, label='Test')

ax.set_xlabel('Visit Type')
ax.set_ylabel('Completion Rate (%)')
ax.set_title('Completion Rate by Visit Type and Group')
ax.set_xticks([i + width / 2 for i in x])
ax.set_xticklabels(labels)
ax.legend()

# Extend the y-axis limit
plt.ylim(0, max(completion_rates) + 10)

# Adding labels to the bars
for bar in bars1:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height + 1, f'{height:.2f}%', ha='center', va='bottom')

for bar in bars2:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, height + 1, f'{height:.2f}%', ha='center', va='bottom')


plt.show()

# %%
# Threshold for cost-effectiveness First Time Visits 
threshold = 0.05  # 5%

# Calculate the observed increase in completion rate
observed_increase = test_first_time_completion_rate - test_repeated_completion_rate

# Check if the observed increase meets the threshold
if observed_increase >= threshold:
    print("The observed increase in completion rate meets or exceeds the 5% threshold.")
else:
    print("The observed increase in completion rate does not meet the 5% threshold.")
# Out:
# The observed increase in completion rate does not meet the 5% threshold.

# %%
# Threshold for cost-effectiveness Repeated Visits

# %%
test_df = df_with_first_engagement[df_with_first_engagement['Variation'] == 'Test']
control_df = df_with_first_engagement[df_with_first_engagement['Variation'] == 'Control']

# Calculate completion rate for test and control groups
test_completion_rate = calculate_completion_rate(test_df)
control_completion_rate = calculate_completion_rate(control_df)

# Data for plotting
groups = ['Control', 'Test']
completion_rates = [control_completion_rate, test_completion_rate]

# Plotting
plt.figure(figsize=(10, 5))
sns.barplot(x=groups, y=completion_rates)

# Extend the y-axis limit
plt.ylim(0, max(completion_rates) + 10)

# Adding labels to the bars
for i in range(len(groups)):
    plt.text(i, completion_rates[i] + 1, f'{completion_rates[i]:.2f}%', ha='center', va='bottom')

# Additional plot settings
plt.title('Completion Rate')
plt.ylabel('Percentage')
plt.xlabel('Group')

# Show plot
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
# Separate control and test groups
df_control = df_merged[df_merged['Variation'] == 'Control']
df_test = df_merged[df_merged['Variation'] == 'Test']

# Control group KPIs
control_avg_time_per_step = calculate_avg_time_per_step(df_control)

# Test group KPIs

test_avg_time_per_step = calculate_avg_time_per_step(df_test)


# Average Time per Step
plt.figure(figsize=(12, 6))
plt.plot(control_avg_time_per_step['process_step'], control_avg_time_per_step['time_diff'], label='Control', marker='o')
plt.plot(test_avg_time_per_step['process_step'], test_avg_time_per_step['time_diff'], label='Test', marker='o')
plt.title('Average Time per Step')
plt.xlabel('Process Step')
plt.ylabel('Time (Seconds)')
plt.legend()
plt.show()

# %%
# Error Rate
plt.figure(figsize=(10, 5))
error_rates = [control_error_rate, test_error_rate]
sns.barplot(x=['Control', 'Test'], y=error_rates)
plt.title('Error Rate')
plt.ylabel('Percentage')

# Extend the y-axis limit
plt.ylim(0, max(error_rates) +3)

# Adding labels to the bars
for i, rate in enumerate(error_rates):
    plt.text(i, rate + 1, f'{rate:.2f}%', ha='center')

plt.show()

# Bounce Rate
plt.figure(figsize=(10, 5))
bounce_rates = [control_bounce_rate, test_bounce_rate]
sns.barplot(x=['Control', 'Test'], y=bounce_rates)
plt.title('Bounce Rate')
plt.ylabel('Percentage')



# Adding labels to the bars
for i, rate in enumerate(bounce_rates):
    plt.text(i, rate + 1, f'{rate:.2f}%', ha='center')

plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df_demo_merged, x='clnt_tenure_yr', hue='Variation', bins=20, kde=True)
plt.title('Distribution of Clients by Tenure (Years) for Test and Control Groups')
plt.xlabel('Tenure (Years)')
plt.ylabel('Frequency')
plt.legend(title='Variation', labels=['Test', 'Control'])  # Switched the order of labels
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Reverse the order of the data for Test and Control groups
df_demo_merged['Variation'] = df_demo_merged['Variation'].map({'Control': 'Test', 'Test': 'Control'})

# Plotting with the reversed order
plt.figure(figsize=(10, 5))
sns.histplot(data=df_demo_merged, x='clnt_tenure_yr', hue='Variation', bins=20, kde=True)
plt.title('Distribution of Clients by Tenure (Years) for Test and Control Groups')
plt.xlabel('Tenure (Years)')
plt.ylabel('Frequency')
plt.legend(title='Variation', labels=['Test', 'Control'])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Separate the data into test and control groups
df_control = df_demo_merged[df_demo_merged['Variation'] == 'Control']
df_test = df_demo_merged[df_demo_merged['Variation'] == 'Test']

# Plotting with the reversed order
plt.figure(figsize=(10, 5))
sns.histplot(data=df_test, x='clnt_tenure_yr', bins=20, kde=True, color='blue', alpha=0.5, label='Test')
sns.histplot(data=df_control, x='clnt_tenure_yr', bins=20, kde=True, color='orange', alpha=0.5, label='Control')
plt.title('Distribution of Clients by Tenure (Years) for Test and Control Groups')
plt.xlabel('Tenure (Years)')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import os
# Define the directory and file path
directory = '../data/clean'
file_path = os.path.join(directory, 'df_with_first_engagement.csv')

# Create the directory if it does not exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame to a CSV file
df_with_first_engagement.to_csv(file_path, index=True)

print(f"File saved successfully at {file_path}")
# Out:
# File saved successfully at ../data/clean/df_with_first_engagement.csv

# %%
file_path = os.path.join(directory, 'df_with_first_engagement.xlsx')
df_with_first_engagement.to_excel(file_path, index=True)
